# %%
#sets in python

set1 = {1,2,3,4,5,6,7}
set2 = {1,2,3,4,5,6}

print(set1.issuperset(set2))
# Out:
# True

# %%
import subprocess
import os

with open('newfile.tct', 'a') as f:
    f.write('This is new file')

# %%
name = input()
age = int(input())
height = float(input())

# Basic file handling in Python

a = 42   # example value

# Safely write 'a' into a text file
with open("output.txt", "w") as file:
    file.write(str(a))

print("Value of 'a' has been written to output.txt")
# Out:
#  876
#  87
#  8
# Value of 'a' has been written to output.txt

# %%
name = input()
age = int(input())
height = float(input())

# %%
# %%writefile students.txt
# Gaurav, 95
# Saurabh, 88
# Satvik, 92
# Out:
# Writing students.txt

# %%
with open('students.txt','r') as file:
    file.write('Name:{name}\n')
    file.write('age:{age}\n')
    file.write('height:{height}\n')
file.close()
country = input()
with open("user")
