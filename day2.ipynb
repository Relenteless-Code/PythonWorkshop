# %%
#syntax of simple if statementr

age= int(input('Enter your age'))
if age >= 18:
    print('Inside If scope')
    print('Eligible for voting')
# Out:
# Enter your age 69
# Inside If scope
# Eligible for voting

# %%
#binary conditional statement if-else
age= int(input('Enter your age'))
if age >= 18 and age <=99:
    print('Eligible for voting')
else  :
    print('Not eligible for voting')
# Out:
# Enter your age 87
# Eligible for voting

# %%
#Nested if-else

year= int(input('enter your year'))
if year%100 == 0:
    if year%4 == 0:
         print('{} is century and leap year'.format(year))
    else:
        print('{} is a century and non-leap year'.format(year))
elif  year % 4 == 0:

    print('{} is non-century and leap year'.format(year))
else:
    print('{} is a non-century and non -leap year'.format(year))
# Out:
# enter your year 6500
# 6500 is century and leap year

# %%
# else-if ladder

grade = int(input('enter your grade'))
if grade <=100 and grade>=91:
    print('Grade A')
elif grade >= 81:
    print('Grade B')
elif grade >=71:
    print('Grade C')
elif grade >= 61:
    print('Grade D')
else :
    print('fail')
# Out:
# enter your grade 87
# Grade B

# %%
#check whether the Number is positive,Negative or zero

num = float(input('Enter number'))
if num > 0:
            print('Number is positive')
elif num == 0:
  print('number is zero')
else:
    print ('Number is negative')
# Out:
# Enter number 978
# Number is positive

# %%
#simple calculator 

# Simple Calculator in Python

def calculator():
    print("Select operation:")
    print("1. Add")
    print("2. Subtract")
    print("3. Multiply")
    print("4. Divide")

    choice = input("Enter choice (1/2/3/4): ")

    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if choice == '1':
        print(f"{num1} + {num2} = {num1 + num2}")
    elif choice == '2':
        print(f"{num1} - {num2} = {num1 - num2}")
    elif choice == '3':
        print(f"{num1} * {num2} = {num1 * num2}")
    elif choice == '4':
        if num2 != 0:
            print(f"{num1} / {num2} = {num1 / num2}")
        else:
            print("Error! Division by zero.")
    else:
        print("Invalid input")

calculator()
# Out:
# Select operation:
# 1. Add
# 2. Subtract
# 3. Multiply
# 4. Divide
# Enter choice (1/2/3/4):  3
# Enter first number:  78
# Enter second number:  8
# 78.0 * 8.0 = 624.0

# %%
#check whether characters are vowels or not

ch= input('enetr charachter')
if ch in "AEIOU" or ch in "aeiou":
    print('{} is a vowel'.format(ch))
else:
    print('{} is not a vowel'.format(ch))
# Out:
# enetr charachter u
# u is a vowel

# %%
#CONVERT UPPERCASE TO LOWERCASE AND LOWERCASE TO UPPERCASE 

char = input('Enter character')
char1 = ord(char) 
if 65<= char1 <=90:
    print(chr(char1+32))
elif 97<= char1 <=122:
    print(chr(char1 - 32))
else:
    print('invalid character')
# Out:
# Enter character h
# H

# %%
#write a program to calculate electricity bill based on following rule
# first 100 units: 0.5$
#next 100 units : 0.75$
#Above 200 units: 1$


units = float(input('enter your units utilised'))
if units <= 100:
    bill = units*0.5
elif units >= 101 and units <= 200:
   bill= (units-100)*0.75+50
else:
  bill = (units-200)*1+120
print('Your total electricity bill is {} dollar'.format(bill))
# Out:
# enter your units utilised 879
# Your total electricity bill is 799.0 dollar

# %%
#write a program to determine if a triangle is valid based on the lenmght of its side


a = float(input('Enter the lenght of the side a'))
b = float(input('Enter the lenght of the side b'))
c = float(input('Enter the lenght of the side c'))

if a + b > c and b+c > a and a+c > b:
          print('This Triangle is valid based on its side')
else:
          print('triangle is invalid')
# Out:
# Enter the lenght of the side a 78
# Enter the lenght of the side b 87
# Enter the lenght of the side c 76
# This Triangle is valid based on its side

# %%
#while loop
#print first n Natural Numbers

num = int(input('enter the Number'))
i=11
while i <= num:
    print(i)
    i=i+1
# Out:
# enter the Number 15
# 11
# 12
# 13
# 14
# 15

# %%
#find the sum of first "n" natural numbers

num = int(input("Enter the Number"))
sum_n = 0
# Out:
# Enter the Number 8

# %%
# Sum of first n natural numbers using while loop

n = int(input("Enter a number: "))
sum_n = 0
i = 1

while i <= n:
    sum_n += i
    i += 1

print("Sum of first", n, "natural numbers is:", sum_n)
# Out:
# Enter a number:  6
# Sum of first 6 natural numbers is: 21

# %%
#sum of first n natural numbers using for loop

num= int(input('enter the number'))
sum = 0
for i in range(1, num+1):
    sum = sum + i
print(f"sum of first {num} number is {sum}")
# Out:
# enter the number 9
# sum of first 9 number is 45

# %%
# WAP to find number is prime or not.
num = int(input("Enter a number: "))

if num > 1:
    for i in range(2, num):
        if num % i == 0:
            print(num, "is NOT a prime number")
            break
    else:
        print(num, "is a PRIME number")

else:
    print(num, "is NOT a prime number")
# Out:
# Enter a number:  0
# 0 is NOT a prime number

# %%
#WAP to find a prime number from a given range  [start-end]
start = int(input('enter start number'))
end = int(input('enter end number'))

for j in range (start,end):
    counter = 0
    if j == 1:
        print('eneter number {} is not a prime number'.format(j))
    elif j = 2:
    print('enetered number {} is even prime number'.format(j))
else:
    for i in range(1, int(
        if j % i == 0:
                   counter += 1
        if counter

# %%
rows = int(input("Enter number of rows: "))

for i in range(1, rows + 1):   # outer loop for rows
    for j in range(1, i + 1):  # inner loop for stars
        print("*", end=" ")
    print()   # move to next line
# Out:
# Enter number of rows:  8
# *
# * *
# * * *
# * * * *
# * * * * *
# * * * * * *
# * * * * * * *
# * * * * * * * *

# %%
rows = int(input("Enter number of rows: "))

for i in range(1, rows + 1):  
    for j in range(1, i + 1): 
        print(j, end=" ")
    print()
# Out:
# Enter number of rows:  9
# 1 ah
# 1 2 ah
# 1 2 3 ah
# 1 2 3 4 ah
# 1 2 3 4 5 ah
# 1 2 3 4 5 6 ah
# 1 2 3 4 5 6 7 ah
# 1 2 3 4 5 6 7 8 ah
# 1 2 3 4 5 6 7 8 9 ah

# %%
rows = int(input("Enter number of rows: "))

for i in range(1, rows + 1):      
    # print spaces
    for j in range(rows - i):
        print(" ", end=" ")
    # print stars
    for k in range(2 * i - 1):
        print("*", end=" ")
    print()
# Out:
# Enter number of rows:  7
#             *
#           * * *
#         * * * * *
#       * * * * * * *
#     * * * * * * * * *
#   * * * * * * * * * * *
# * * * * * * * * * * * * *
